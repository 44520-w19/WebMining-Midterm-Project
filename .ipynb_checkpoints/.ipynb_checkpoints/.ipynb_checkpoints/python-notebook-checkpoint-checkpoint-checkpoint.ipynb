# %%
#from github_token import ACCESS_TOKEN
from github import Github
import networkx as nx
import matplotlib.pyplot as plt
import pickle


access_token = '22228a29e7cb96ef8006f9b53f1795954017979c'
client = Github(access_token, per_page=100)
repo = client.get_repo('doocs/advanced-java')
gazers = repo.get_stargazers()

with open('stargazers.pkl', 'wb') as f:
    pickle.dump(gazers, f)

with open('stargazers.pkl', 'rb') as f:
    gazers_pkl = pickle.load(f)

#g = nx.DiGraph()
#g.add_node(repo.name, type='repo')

#users = graph_stargazers(g, repo, client)

#for user in users:
#    graph_userLang(g, user, True)
    
#nx.write_gpickle(g, 'bigGraph')

#labels = {n:n for n in g.nodes()}
#nx.draw(g, nx.spring_layout(g), arrows=True, ax=ax,
#       node_size=100, edge_color='#aaaaaa',
#       node_color=graph_colors(g), alpha=0.8,
#       font_size=12, labels = labels, node_shape='*')



language_count = 0
for i in range(20):
    #only gets 20 user login names
    user = client.get_user(gazers[i].login)
    #list of all repos for each user
    newrepos = user.get_repos()
    #the first repo in each users repos
    print(newrepos[0])
    #name of first repo
    print(newrepos[0].name)
    #users login name
    print(user.login)
    language_count = 0
    #checks all repos in each of 20 stargazers and prints their languages of each repo
    for repo in newrepos:
        if (repo.language != None):
            print(repo.language)
            #keeps count of how many repos each stargazer has
            language_count = language_count + 1
    print(language_count)
#print(dir(repos))
#returns user login of 20 stargazers in list
def graph_stargazers(graph, repo, client):
    gazers = repo.get_stargazers()
    for i in range(20):
        user = client.get_user(gazers[i].login)
        graph.add_node(user, type='user')
        graph.add_edge(user, repo.name, type='gazes')
    return user

#returns a list of repos for the user
def graph_userLang(graph, user, lang=False):
    repos = user.get_repos()
    for repo in repos:
        graph.add_node(repo.name, type='repo')
        graph.add_edge(user.login, repo.name, type='owns')
        if lang:
            graph.add_node(repo.language, type='lang')
            graph.add_edge(user.login, repo.language, type='uses')
            graph.add_edge(repo.name, repo.language, type='speaks')
    return repos

def graph_colors(graph):
    colormap = {'user': 'green', 'lang':'violet', 'repo': 'blue'}
    colorlist = []
    for node in graph.nodes():
        nodetype = graph.nodes.data()[node]['type']
        colorlist.append(colormap.get(nodetype, 'black'))
    return colorlist


g = nx.DiGraph()
g.add_node(repo.name, type='repo')

users = graph_stargazers(g, repo, client)

for user in users:
    graph_userLang(g, user, True)
    
nx.write_gpickle(g, 'bigGraph')

labels = {n:n for n in g.nodes()}
nx.draw(g, nx.spring_layout(g), arrows=True, ax=ax,
       node_size=100, edge_color='#aaaaaa',
       node_color=graph_colors(g), alpha=0.8,
       font_size=12, labels = labels, node_shape='*')
# Out:
# Repository(full_name="WJL3333/aliyun_UBUNTU_code")
# aliyun_UBUNTU_code
# WJL3333
# Python
# Java
# Java
# Java
# HTML
# 5
# Repository(full_name="Snailclimb/2019_campus_apply")
# 2019_campus_apply
# Snailclimb
# Java
# Java
# Java
# HTML
# CoffeeScript
# JavaScript
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Python
# Java
# C++
# Python
# HTML
# Java
# Java
# Java
# JavaScript
# Java
# JavaScript
# JavaScript
# Java
# JavaScript
# 28
# Repository(full_name="flyingbeans/30min_guides")
# 30min_guides
# flyingbeans
# Java
# Java
# Java
# Java
# Java
# Shell
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# JavaScript
# Java
# Java
# Java
# C++
# TeX
# Shell
# Shell
# Java
# Java
# Java
# C
# Java
# Java
# Java
# Java
# Python
# Java
# Java
# Java
# Java
# Java
# Java
# JavaScript
# Java
# Java
# JavaScript
# C++
# Vim script
# Java
# Ruby
# Java
# Java
# Java
# Java
# Java
# Python
# 54
# Repository(full_name="Gandalf-z/Fantasy")
# Fantasy
# Gandalf-z
# Java
# HTML
# Java
# JavaScript
# 4
# Repository(full_name="Emors/CS-Notes")
# CS-Notes
# Emors
# Java
# 1
# Repository(full_name="chocolatemetoprolol/AdvertisementView")
# AdvertisementView
# chocolatemetoprolol
# Swift
# Objective-C
# Swift
# Swift
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Swift
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# JavaScript
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Swift
# Swift
# Objective-C
# Objective-C
# Swift
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Swift
# Objective-C
# Objective-C
# C++
# Swift
# Swift
# Objective-C
# Objective-C
# Objective-C
# Java
# JavaScript
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# Objective-C
# 52
# Repository(full_name="johnsonDo/DesignPattern")
# DesignPattern
# johnsonDo
# Java
# Java
# Java
# 3
# Repository(full_name="siliang42/eureka-client-demo")
# eureka-client-demo
# siliang42
# Java
# Java
# Java
# Java
# Go
# Java
# Python
# Go
# Shell
# Shell
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# 19
# Repository(full_name="SeanHongXing/SuoHa")
# SuoHa
# SeanHongXing
# Java
# 1
# Repository(full_name="tsxf/CS-Notes")
# CS-Notes
# tsxf
# Java
# Java
# HTML
# 3
# Repository(full_name="CTWW/CS-Notes")
# CS-Notes
# CTWW
# 0
# Repository(full_name="hao031410/bootstrap")
# bootstrap
# hao031410
# JavaScript
# HTML
# JavaScript
# Java
# 4
# Repository(full_name="numberchc/24PointGame")
# 24PointGame
# numberchc
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# 8
# Repository(full_name="meteorxht/beauty_ssm_dubbo")
# beauty_ssm_dubbo
# meteorxht
# Java
# HTML
# Java
# Java
# HTML
# Java
# Java
# Java
# 8
# Repository(full_name="DellonShao/leetcode")
# leetcode
# DellonShao
# Java
# Java
# PHP
# 3
# Repository(full_name="kedup/2017-04-13-_CollectiveIntelligence")
# 2017-04-13-_CollectiveIntelligence
# kedup
# Python
# Python
# PHP
# JavaScript
# Python
# Java
# C
# Java
# Java
# Python
# JavaScript
# HTML
# HTML
# Kotlin
# JavaScript
# Java
# Java
# Shell
# Java
# Java
# HTML
# Python
# JavaScript
# Python
# Python
# C++
# HTML
# Shell
# Java
# Java
# Java
# Java
# 32
# Repository(full_name="cenjieHo/ABCPrinter")
# ABCPrinter
# cenjieHo
# C++
# HTML
# Java
# HTML
# Java
# Java
# Java
# Java
# Python
# Java
# JavaScript
# C
# 12
# Repository(full_name="Nanmen/500lines")
# 500lines
# Nanmen
# JavaScript
# C
# Java
# JavaScript
# JavaScript
# JavaScript
# Shell
# Java
# Java
# JavaScript
# Java
# HTML
# JavaScript
# HTML
# Java
# Groovy
# CSS
# JavaScript
# Python
# Java
# Java
# Java
# JavaScript
# Kotlin
# C
# Shell
# Java
# HTML
# Java
# JavaScript
# JavaScript
# C
# JavaScript
# HTML
# JavaScript
# Java
# C++
# Java
# Java
# Python
# JavaScript
# Python
# Python
# JavaScript
# JavaScript
# Scala
# JavaScript
# Python
# Java
# Java
# Java
# Java
# Java
# GCC Machine Description
# JavaScript
# Java
# C
# JavaScript
# Java
# Python
# Java
# Python
# JavaScript
# 63
# Repository(full_name="liunianmiyu/corejava")
# corejava
# liunianmiyu
# Java
# CSS
# JavaScript
# JavaScript
# 4
# Repository(full_name="raynordlk/job")
# job
# raynordlk
# Lua
# 1
# Traceback (most recent call last):
#
#   File "<ipython-input-4-8b9ae7cef3bc>", line 91, in <module>
#     users = graph_stargazers(g, repo, client)
#
#   File "<ipython-input-4-8b9ae7cef3bc>", line 62, in graph_stargazers
#     user = client.get_user(gazers[i].login)
#
#   File "C:\Users\jzech\Anaconda3\lib\site-packages\github\PaginatedList.py", line 56, in __getitem__
#     return self.__elements[index]
#
# IndexError: list index out of range
